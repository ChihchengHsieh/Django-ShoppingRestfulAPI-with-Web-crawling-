# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = 'https://www.coles.com.au/catalogues-and-specials/view-all-available-catalogues#view=list&saleId=28226&areaName=c-qld-met'

# %%
url = 'https://www.woolworths.com.au/shop/search/products?searchTerm=ogx'

# %%
res = requests.get(url,headers= {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'})

# %%
# res = requests.get('https://www.coles.com.au/catalogues-and-specials/view-all-available-catalogues#view=list&saleId=28226&areaName=c-qld-met')

# %%
res.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<html class="no-js conversational-checkout-wizard sf-expand-personal-shopper-comment mf-expand-personal-shopper-comment lf-expand-personal-shopper-comment click-and-collect-store-search enable-get-edr-points-balance-on-login recipe-social-media recipe-export-print remember-me-enabled enable-checkout-with-paypal enable-custom-coupon-promotion-success-message show-accepted-cards-in-checkout wos4048 enable-my-invoices-page enable-rich-relevance-recommendations rr-show-placements-in-category-pages rr-show-placements-in-homepage-pages rr-show-placements-in-specials-group-pages" lang="en-AU" ng-app="wowApp" ng-strict-di="true">\r\n<head ng-controller="PageMetadataController as metaController">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n    <meta name="buildVersion" content="2019.612.10.0" />\r\n    <meta name="frontendVersion" content="2019.612.4" />\r\n    <meta n
# ...

# %%
from IPython.display import HTML

# %%
import urllib

# %%
r = urllib.request.urlopen(url)
res = str(r.read())

# %%
# Out:
# b''

# %%
HTML(res)
# Out:
# b'\r\n\r\n<!doctype html>\r\n<!--[if lt IE 7 ]> <html lang="en" class="no-js ie6 lt-ie11 lt-ie10 lt-ie9 lt-ie8 lt-ie7" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#"> <![endif]-->\r\n<!--[if IE 7 ]>    <html lang="en" class="no-js ie7 lt-ie11 lt-ie10 lt-ie9 lt-ie8" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#"> <![endif]-->\r\n<!--[if IE 8 ]>    <html lang="en" class="no-js ie8 lt-ie11 lt-ie10 lt-ie9" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#"> <![endif]-->\r\n<!--[if IE 9 ]>    <html lang="en" class="no-js ie9 lt-ie11 lt-ie10" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.
# ...
